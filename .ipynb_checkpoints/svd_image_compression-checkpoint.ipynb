# %%
import numpy as np
from matplotlib import animation
from matplotlib.image import imread
import matplotlib.pyplot as plt

img = imread('mealybugs.jpg')
img = np.mean(img, -1)

plt.figure(figsize=(8, 5))
plt.axis('off')
plt.title('Original')
plt.imshow(img, cmap='gray')
plt.show()

# %%
## Compute SVD
U, S, VT = np.linalg.svd(img, full_matrices=False)
S = np.diag(S)

plt.figure(figsize=(16,10))

j = 1
for r in (5, 20, 100, 250):
    # Construct approximate image
    img_approx = U[:,:r] @ S[:r,:r] @ VT[:r,:]
    plt.subplot('22'+str(j))
    j += 1
    plt.title('r = '+str(r))
    plt.axis('off')
    plt.imshow(img_approx, cmap='gray')

plt.show()

# %%
# Plot Sigma and Cumulative energy in first 'r' columns/rows
plt.figure(figsize=(16,10))
plt.subplot('121')
plt.title('Singular Values or Sigma Values')
plt.semilogy(np.diag(S))

plt.subplot('122')
plt.title('Cumulative Sum of first r Singular Values')
plt.plot(np.cumsum(np.diag(S))/np.sum(np.diag(S)))

plt.show()

# %%
# Correlation Matrix
AAT = img @ np.transpose(img)
ATA = np.transpose(img) @ img

plt.figure(figsize=(16,10))
plt.subplot('121')
plt.axis('off')
plt.title('AAT')
plt.imshow(AAT, cmap='gray')

plt.subplot('122')
plt.axis('off')
plt.title('ATA')
plt.imshow(ATA, cmap='gray')

plt.show()

# %%
# Generate animation of image compression
# Optimal maximum rank value 'r' can be inferred from plot of Sigma values
# Most of the energy of the image is captured within the first 250 vectors
max_r = 250

def truncate_USV(r):
    img_approx = U[:,:r] @ S[:r,:r] @ VT[:r,:]    
    return img_approx

# Animation of image over point of truncation of SVD
fig, ax = plt.subplots(figsize=(15, 10))
title = ax.set_title('Percentage of Data: 0%', fontsize=20)
ax.set_axis_off()
im = ax.imshow(img, cmap='gray')
fig.tight_layout()

def init():
    im.set_array(truncate_USV(5))
    title.set_text('Percentage of Data: ' + str(5*100/U.shape[1]) + '%')
    return [im]

def animate(i):
    im.set_array(truncate_USV(i))
    title.set_text('Percentage of Data: ' + str(i*100/U.shape[1]) + '%')
    return [im]

ani = animation.FuncAnimation(fig, animate, np.arange(0, max_r, 5), init_func=init, blit=True)
ani.save('img_compress_anim.avi', fps=6)
